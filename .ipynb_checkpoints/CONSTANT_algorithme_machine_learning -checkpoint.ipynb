# %% [markdown]
# # Machine learning 1

# %% [markdown]
# # Import des Bibliothèques

# %%
import pandas
pandas.__version__
# Out:
# '0.24.2'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sqlalchemy import create_engine
import pymysql 
from scipy import stats
import dash
import dash_core_components as dcc
import dash_html_components as html

# %% [markdown]
# # 1. Lecture du fichier CSV et Récupération des données.

# %%
car_data = pandas.read_csv('carData.csv')
car_data
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0             ritz  2014           3.35           5.59       27000    Petrol
# 1              sx4  2013           4.75           9.54       43000    Diesel
# 2             ciaz  2017           7.25           9.85        6900    Petrol
# 3          wagon r  2011           2.85           4.15        5200    Petrol
# 4            swift  2014           4.60           6.87       42450    Diesel
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# 6             ciaz  2015           6.75           8.12       18796    Petrol
# 7          s cross  2015           6.50           8.61       33429    Diesel
# 8             ciaz  2016           8.75           8.89       20273    Diesel
# 9             ciaz  2015           7.45           8.92       42367    Diesel
# 10        alto 800  2017           2.85           3.60        2135    Petrol
# 11            ciaz  2015           6.85          10.38       51000    Diesel
# 12            ciaz  2015           7.50           9.94       15000    Petrol
# 13          ertiga  2015           6.10           7.71       26000    Petrol
# 14           dzire  2009           2.25           7.21       77427    Petrol
# 15          ertiga  2016           7.75          10.79       43000    Diesel
# 16          ertiga  2015           7.25          10.79       41678    Diesel
# 17          ertiga  2016           7.75          10.79       43000    Diesel
# 18         wagon r  2015           3.25           5.09       35500       CNG
# 19             sx4  2010           2.65           7.98       41442    Petrol
# 20        alto k10  2016           2.85           3.95       25000    Petrol
# 21           ignis  2017           4.90           5.71        2400    Petrol
# 22             sx4  2011           4.40           8.01       50000    Petrol
# 23        alto k10  2014           2.50           3.46       45280    Petrol
# 24         wagon r  2013           2.90           4.41       56879    Petrol
# 25           swift  2011           3.00           4.99       20000    Petrol
# 26           swift  2013           4.15           5.87       55138    Petrol
# 27           swift  2017           6.00           6.49       16200    Petrol
# 28        alto k10  2010           1.95           3.95       44542    Petrol
# 29            ciaz  2015           7.45          10.38       45000    Diesel
# ..             ...   ...            ...            ...         ...       ...
# 271           city  2009           3.00          10.00       69562    Petrol
# 272           city  2015           7.50          10.00       27600    Petrol
# 273           jazz  2010           2.25           7.50       61203    Petrol
# 274           brio  2014           5.30           6.80       16500    Petrol
# 275           city  2016          10.90          13.60       30753    Petrol
# 276           city  2015           8.65          13.60       24800    Petrol
# 277           city  2015           9.70          13.60       21780    Petrol
# 278           jazz  2016           6.00           8.40        4000    Petrol
# 279           city  2014           6.25          13.60       40126    Petrol
# 280           brio  2015           5.25           5.90       14465    Petrol
# 281           city  2006           2.10           7.60       50456    Petrol
# 282           city  2014           8.25          14.00       63000    Diesel
# 283           city  2016           8.99          11.80        9010    Petrol
# 284           brio  2013           3.50           5.90        9800    Petrol
# 285           jazz  2016           7.40           8.50       15059    Petrol
# 286           jazz  2016           5.65           7.90       28569    Petrol
# 287          amaze  2015           5.75           7.50       44000    Petrol
# 288           city  2015           8.40          13.60       34000    Petrol
# 289           city  2016          10.11          13.60       10980    Petrol
# 290          amaze  2014           4.50           6.40       19000    Petrol
# 291           brio  2015           5.40           6.10       31427    Petrol
# 292           jazz  2016           6.40           8.40       12000    Petrol
# 293           city  2010           3.25           9.90       38000    Petrol
# 294          amaze  2014           3.75           6.80       33019    Petrol
# 295           city  2015           8.55          13.09       60076    Diesel
# 296           city  2016           9.50          11.60       33988    Diesel
# 297           brio  2015           4.00           5.90       60000    Petrol
# 298           city  2009           3.35          11.00       87934    Petrol
# 299           city  2017          11.50          12.50        9000    Diesel
# 300           brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# 5        Dealer       Manual      0
# 6        Dealer       Manual      0
# 7        Dealer       Manual      0
# 8        Dealer       Manual      0
# 9        Dealer       Manual      0
# 10       Dealer       Manual      0
# 11       Dealer       Manual      0
# 12       Dealer    Automatic      0
# 13       Dealer       Manual      0
# 14       Dealer       Manual      0
# 15       Dealer       Manual      0
# 16       Dealer       Manual      0
# 17       Dealer       Manual      0
# 18       Dealer       Manual      0
# 19       Dealer       Manual      0
# 20       Dealer       Manual      0
# 21       Dealer       Manual      0
# 22       Dealer    Automatic      0
# 23       Dealer       Manual      0
# 24       Dealer       Manual      0
# 25       Dealer       Manual      0
# 26       Dealer       Manual      0
# 27   Individual       Manual      0
# 28       Dealer       Manual      0
# 29       Dealer       Manual      0
# ..          ...          ...    ...
# 271      Dealer       Manual      0
# 272      Dealer       Manual      0
# 273      Dealer       Manual      0
# 274      Dealer       Manual      0
# 275      Dealer    Automatic      0
# 276      Dealer       Manual      0
# 277      Dealer       Manual      0
# 278      Dealer       Manual      0
# 279      Dealer       Manual      0
# 280      Dealer       Manual      0
# 281      Dealer       Manual      0
# 282      Dealer       Manual      0
# 283      Dealer       Manual      0
# 284      Dealer       Manual      0
# 285      Dealer    Automatic      0
# 286      Dealer       Manual      0
# 287      Dealer    Automatic      0
# 288      Dealer       Manual      0
# 289      Dealer       Manual      0
# 290      Dealer       Manual      0
# 291      Dealer       Manual      0
# 292      Dealer       Manual      0
# 293      Dealer       Manual      0
# 294      Dealer       Manual      0
# 295      Dealer       Manual      0
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %% [markdown]
# # 2. Explorer les données

# %%
car_data.size
# Out:
# 2709

# %%
car_data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
# moyenne
car_data.mean()
# Out:
# Year              2013.627907
# Selling_Price        4.661296
# Present_Price        7.628472
# Kms_Driven       36947.205980
# Owner                0.043189
# dtype: float64

# %%
# mediane
car_data.median()
# Out:
# Year              2014.0
# Selling_Price        3.6
# Present_Price        6.4
# Kms_Driven       32000.0
# Owner                0.0
# dtype: float64

# %%
car_data.quantile([0.25, 0.5, 0.75])
# Out:
#         Year  Selling_Price  Present_Price  Kms_Driven  Owner
# 0.25  2012.0            0.9            1.2     15000.0    0.0
# 0.50  2014.0            3.6            6.4     32000.0    0.0
# 0.75  2016.0            6.0            9.9     48767.0    0.0

# %%
# Historigramme
plt.rcParams["figure.figsize"]=20,20
car_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9ccfc1bd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9ccf409b00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9ccf3b90b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9ccf3df630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9ccf388b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9ccf3370f0>]],
#       dtype=object)

# %% [markdown]
# # 3. Charger vos données dans une base de données MySQL

# %%
engine = create_engine('mysql+pymysql://amos:admin@localhost/carData')
dbConnection=engine.connect()
car_data.to_sql('car',dbConnection, if_exists='append',index=False)


frame = pd.read_sql("select * from carData.car", dbConnection);
frame
# Out:
#         id       car_name  year  selling_price  present_price  kms_driven  \
# 0        1           ritz  2014           3.35           5.59       27000
# 1        2            sx4  2013           4.75           9.54       43000
# 2        3           ciaz  2017           7.25           9.85        6900
# 3        4        wagon r  2011           2.85           4.15        5200
# 4        5          swift  2014           4.60           6.87       42450
# 5        6  vitara brezza  2018           9.25           9.83        2071
# 6        7           ciaz  2015           6.75           8.12       18796
# 7        8        s cross  2015           6.50           8.61       33429
# 8        9           ciaz  2016           8.75           8.89       20273
# 9       10           ciaz  2015           7.45           8.92       42367
# 10      11       alto 800  2017           2.85           3.60        2135
# 11      12           ciaz  2015           6.85          10.38       51000
# 12      13           ciaz  2015           7.50           9.94       15000
# 13      14         ertiga  2015           6.10           7.71       26000
# 14      15          dzire  2009           2.25           7.21       77427
# 15      16         ertiga  2016           7.75          10.79       43000
# 16      17         ertiga  2015           7.25          10.79       41678
# 17      18         ertiga  2016           7.75          10.79       43000
# 18      19        wagon r  2015           3.25           5.09       35500
# 19      20            sx4  2010           2.65           7.98       41442
# 20      21       alto k10  2016           2.85           3.95       25000
# 21      22          ignis  2017           4.90           5.71        2400
# 22      23            sx4  2011           4.40           8.01       50000
# 23      24       alto k10  2014           2.50           3.46       45280
# 24      25        wagon r  2013           2.90           4.41       56879
# 25      26          swift  2011           3.00           4.99       20000
# 26      27          swift  2013           4.15           5.87       55138
# 27      28          swift  2017           6.00           6.49       16200
# 28      29       alto k10  2010           1.95           3.95       44542
# 29      30           ciaz  2015           7.45          10.38       45000
# ...    ...            ...   ...            ...            ...         ...
# 1475  1476           city  2009           3.00          10.00       69562
# 1476  1477           city  2015           7.50          10.00       27600
# 1477  1478           jazz  2010           2.25           7.50       61203
# 1478  1479           brio  2014           5.30           6.80       16500
# 1479  1480           city  2016          10.90          13.60       30753
# 1480  1481           city  2015           8.65          13.60       24800
# 1481  1482           city  2015           9.70          13.60       21780
# 1482  1483           jazz  2016           6.00           8.40        4000
# 1483  1484           city  2014           6.25          13.60       40126
# 1484  1485           brio  2015           5.25           5.90       14465
# 1485  1486           city  2006           2.10           7.60       50456
# 1486  1487           city  2014           8.25          14.00       63000
# 1487  1488           city  2016           8.99          11.80        9010
# 1488  1489           brio  2013           3.50           5.90        9800
# 1489  1490           jazz  2016           7.40           8.50       15059
# 1490  1491           jazz  2016           5.65           7.90       28569
# 1491  1492          amaze  2015           5.75           7.50       44000
# 1492  1493           city  2015           8.40          13.60       34000
# 1493  1494           city  2016          10.11          13.60       10980
# 1494  1495          amaze  2014           4.50           6.40       19000
# 1495  1496           brio  2015           5.40           6.10       31427
# 1496  1497           jazz  2016           6.40           8.40       12000
# 1497  1498           city  2010           3.25           9.90       38000
# 1498  1499          amaze  2014           3.75           6.80       33019
# 1499  1500           city  2015           8.55          13.09       60076
# 1500  1501           city  2016           9.50          11.60       33988
# 1501  1502           brio  2015           4.00           5.90       60000
# 1502  1503           city  2009           3.35          11.00       87934
# 1503  1504           city  2017          11.50          12.50        9000
# 1504  1505           brio  2016           5.30           5.90        5464
#
#      fuel_type seller_type transmission  owner
# 0       Petrol      Dealer       Manual      0
# 1       Diesel      Dealer       Manual      0
# 2       Petrol      Dealer       Manual      0
# 3       Petrol      Dealer       Manual      0
# 4       Diesel      Dealer       Manual      0
# 5       Diesel      Dealer       Manual      0
# 6       Petrol      Dealer       Manual      0
# 7       Diesel      Dealer       Manual      0
# 8       Diesel      Dealer       Manual      0
# 9       Diesel      Dealer       Manual      0
# 10      Petrol      Dealer       Manual      0
# 11      Diesel      Dealer       Manual      0
# 12      Petrol      Dealer    Automatic      0
# 13      Petrol      Dealer       Manual      0
# 14      Petrol      Dealer       Manual      0
# 15      Diesel      Dealer       Manual      0
# 16      Diesel      Dealer       Manual      0
# 17      Diesel      Dealer       Manual      0
# 18         CNG      Dealer       Manual      0
# 19      Petrol      Dealer       Manual      0
# 20      Petrol      Dealer       Manual      0
# 21      Petrol      Dealer       Manual      0
# 22      Petrol      Dealer    Automatic      0
# 23      Petrol      Dealer       Manual      0
# 24      Petrol      Dealer       Manual      0
# 25      Petrol      Dealer       Manual      0
# 26      Petrol      Dealer       Manual      0
# 27      Petrol  Individual       Manual      0
# 28      Petrol      Dealer       Manual      0
# 29      Diesel      Dealer       Manual      0
# ...        ...         ...          ...    ...
# 1475    Petrol      Dealer       Manual      0
# 1476    Petrol      Dealer       Manual      0
# 1477    Petrol      Dealer       Manual      0
# 1478    Petrol      Dealer       Manual      0
# 1479    Petrol      Dealer    Automatic      0
# 1480    Petrol      Dealer       Manual      0
# 1481    Petrol      Dealer       Manual      0
# 1482    Petrol      Dealer       Manual      0
# 1483    Petrol      Dealer       Manual      0
# 1484    Petrol      Dealer       Manual      0
# 1485    Petrol      Dealer       Manual      0
# 1486    Diesel      Dealer       Manual      0
# 1487    Petrol      Dealer       Manual      0
# 1488    Petrol      Dealer       Manual      0
# 1489    Petrol      Dealer    Automatic      0
# 1490    Petrol      Dealer       Manual      0
# 1491    Petrol      Dealer    Automatic      0
# 1492    Petrol      Dealer       Manual      0
# 1493    Petrol      Dealer       Manual      0
# 1494    Petrol      Dealer       Manual      0
# 1495    Petrol      Dealer       Manual      0
# 1496    Petrol      Dealer       Manual      0
# 1497    Petrol      Dealer       Manual      0
# 1498    Petrol      Dealer       Manual      0
# 1499    Diesel      Dealer       Manual      0
# 1500    Diesel      Dealer       Manual      0
# 1501    Petrol      Dealer       Manual      0
# 1502    Petrol      Dealer       Manual      0
# 1503    Diesel      Dealer       Manual      0
# 1504    Petrol      Dealer       Manual      0
#
# [1505 rows x 10 columns]

# %% [markdown]
# # 4. Visualiser les données grâce à la librairie Seaborn

# %%
# Catplot 
sns.catplot(x='fuel_type',y='present_price', data=frame, jitter='0.25')

# %%
frame.plot.scatter("kms_driven", "selling_price", c="year", colormap='viridis',figsize=(12, 8))

# %%
X = frame.iloc[0:len(car_data),3]
Y = frame.iloc[0:len(car_data),4]

# %%
axes = plt.axes()
axes.grid()
plt.scatter(X,Y)
plt.show()

# %%
frame[frame["year"]==2008].selling_price,
# Out:
# (42      1.95
#  94      4.00
#  184     0.25
#  185     0.25
#  190     0.20
#  194     0.20
#  196     0.17
#  343     1.95
#  395     4.00
#  485     0.25
#  486     0.25
#  491     0.20
#  495     0.20
#  497     0.17
#  644     1.95
#  696     4.00
#  786     0.25
#  787     0.25
#  792     0.20
#  796     0.20
#  798     0.17
#  945     1.95
#  997     4.00
#  1087    0.25
#  1088    0.25
#  1093    0.20
#  1097    0.20
#  1099    0.17
#  1246    1.95
#  1298    4.00
#  1388    0.25
#  1389    0.25
#  1394    0.20
#  1398    0.20
#  1400    0.17
#  Name: selling_price, dtype: float64,)

# %%
df_2009 = frame[frame["year"]==2009]
print(df_2009)
# Out:
#         id                   car_name  year  selling_price  present_price  \
# 14      15                      dzire  2009           2.25           7.21
# 55      56              corolla altis  2009           3.60          15.04
# 90      91              corolla altis  2009           3.80          18.61
# 125    126  Royal Enfield Classic 500  2009           0.90           1.75
# 271    272                       city  2009           3.00          10.00
# 298    299                       city  2009           3.35          11.00
# 315    316                      dzire  2009           2.25           7.21
# 356    357              corolla altis  2009           3.60          15.04
# 391    392              corolla altis  2009           3.80          18.61
# 426    427  Royal Enfield Classic 500  2009           0.90           1.75
# 572    573                       city  2009           3.00          10.00
# 599    600                       city  2009           3.35          11.00
# 616    617                      dzire  2009           2.25           7.21
# 657    658              corolla altis  2009           3.60          15.04
# 692    693              corolla altis  2009           3.80          18.61
# 727    728  Royal Enfield Classic 500  2009           0.90           1.75
# 873    874                       city  2009           3.00          10.00
# 900    901                       city  2009           3.35          11.00
# 917    918                      dzire  2009           2.25           7.21
# 958    959              corolla altis  2009           3.60          15.04
# 993    994              corolla altis  2009           3.80          18.61
# 1028  1029  Royal Enfield Classic 500  2009           0.90           1.75
# 1174  1175                       city  2009           3.00          10.00
# 1201  1202                       city  2009           3.35          11.00
# 1218  1219                      dzire  2009           2.25           7.21
# 1259  1260              corolla altis  2009           3.60          15.04
# 1294  1295              corolla altis  2009           3.80          18.61
# 1329  1330  Royal Enfield Classic 500  2009           0.90           1.75
# 1475  1476                       city  2009           3.00          10.00
# 1502  1503                       city  2009           3.35          11.00
#
#       kms_driven fuel_type seller_type transmission  owner
# 14         77427    Petrol      Dealer       Manual      0
# 55         70000    Petrol      Dealer    Automatic      0
# 90         62000    Petrol      Dealer       Manual      0
# 125        40000    Petrol  Individual       Manual      0
# 271        69562    Petrol      Dealer       Manual      0
# 298        87934    Petrol      Dealer       Manual      0
# 315        77427    Petrol      Dealer       Manual      0
# 356        70000    Petrol      Dealer    Automatic      0
# 391        62000    Petrol      Dealer       Manual      0
# 426        40000    Petrol  Individual       Manual      0
# 572        69562    Petrol      Dealer       Manual      0
# 599        87934    Petrol      Dealer       Manual      0
# 616        77427    Petrol      Dealer       Manual      0
# 657        70000    Petrol      Dealer    Automatic      0
# 692        62000    Petrol      Dealer       Manual      0
# 727        40000    Petrol  Individual       Manual      0
# 873        69562    Petrol      Dealer       Manual      0
# 900        87934    Petrol      Dealer       Manual      0
# 917        77427    Petrol      Dealer       Manual      0
# 958        70000    Petrol      Dealer    Automatic      0
# 993        62000    Petrol      Dealer       Manual      0
# 1028       40000    Petrol  Individual       Manual      0
# 1174       69562    Petrol      Dealer       Manual      0
# 1201       87934    Petrol      Dealer       Manual      0
# 1218       77427    Petrol      Dealer       Manual      0
# 1259       70000    Petrol      Dealer    Automatic      0
# 1294       62000    Petrol      Dealer       Manual      0
# 1329       40000    Petrol  Individual       Manual      0
# 1475       69562    Petrol      Dealer       Manual      0
# 1502       87934    Petrol      Dealer       Manual      0

# %%
df_2009.plot.scatter("kms_driven", "selling_price", c="year", colormap='viridis',figsize=(12, 8))

# %%
# La visualisation sur une année
df_2009_frame = frame[frame["year"]==2009]
print(df_2009_frame)
# Out:
#         id                   car_name  year  selling_price  present_price  \
# 14      15                      dzire  2009           2.25           7.21
# 55      56              corolla altis  2009           3.60          15.04
# 90      91              corolla altis  2009           3.80          18.61
# 125    126  Royal Enfield Classic 500  2009           0.90           1.75
# 271    272                       city  2009           3.00          10.00
# 298    299                       city  2009           3.35          11.00
# 315    316                      dzire  2009           2.25           7.21
# 356    357              corolla altis  2009           3.60          15.04
# 391    392              corolla altis  2009           3.80          18.61
# 426    427  Royal Enfield Classic 500  2009           0.90           1.75
# 572    573                       city  2009           3.00          10.00
# 599    600                       city  2009           3.35          11.00
# 616    617                      dzire  2009           2.25           7.21
# 657    658              corolla altis  2009           3.60          15.04
# 692    693              corolla altis  2009           3.80          18.61
# 727    728  Royal Enfield Classic 500  2009           0.90           1.75
# 873    874                       city  2009           3.00          10.00
# 900    901                       city  2009           3.35          11.00
# 917    918                      dzire  2009           2.25           7.21
# 958    959              corolla altis  2009           3.60          15.04
# 993    994              corolla altis  2009           3.80          18.61
# 1028  1029  Royal Enfield Classic 500  2009           0.90           1.75
# 1174  1175                       city  2009           3.00          10.00
# 1201  1202                       city  2009           3.35          11.00
# 1218  1219                      dzire  2009           2.25           7.21
# 1259  1260              corolla altis  2009           3.60          15.04
# 1294  1295              corolla altis  2009           3.80          18.61
# 1329  1330  Royal Enfield Classic 500  2009           0.90           1.75
# 1475  1476                       city  2009           3.00          10.00
# 1502  1503                       city  2009           3.35          11.00
#
#       kms_driven fuel_type seller_type transmission  owner
# 14         77427    Petrol      Dealer       Manual      0
# 55         70000    Petrol      Dealer    Automatic      0
# 90         62000    Petrol      Dealer       Manual      0
# 125        40000    Petrol  Individual       Manual      0
# 271        69562    Petrol      Dealer       Manual      0
# 298        87934    Petrol      Dealer       Manual      0
# 315        77427    Petrol      Dealer       Manual      0
# 356        70000    Petrol      Dealer    Automatic      0
# 391        62000    Petrol      Dealer       Manual      0
# 426        40000    Petrol  Individual       Manual      0
# 572        69562    Petrol      Dealer       Manual      0
# 599        87934    Petrol      Dealer       Manual      0
# 616        77427    Petrol      Dealer       Manual      0
# 657        70000    Petrol      Dealer    Automatic      0
# 692        62000    Petrol      Dealer       Manual      0
# 727        40000    Petrol  Individual       Manual      0
# 873        69562    Petrol      Dealer       Manual      0
# 900        87934    Petrol      Dealer       Manual      0
# 917        77427    Petrol      Dealer       Manual      0
# 958        70000    Petrol      Dealer    Automatic      0
# 993        62000    Petrol      Dealer       Manual      0
# 1028       40000    Petrol  Individual       Manual      0
# 1174       69562    Petrol      Dealer       Manual      0
# 1201       87934    Petrol      Dealer       Manual      0
# 1218       77427    Petrol      Dealer       Manual      0
# 1259       70000    Petrol      Dealer    Automatic      0
# 1294       62000    Petrol      Dealer       Manual      0
# 1329       40000    Petrol  Individual       Manual      0
# 1475       69562    Petrol      Dealer       Manual      0
# 1502       87934    Petrol      Dealer       Manual      0

# %%
x = frame['selling_price']
y = frame['year']

plt.plot(x,y)

# %%
plt.subplot(121)
plt.boxplot([[1, 2, 3, 4, 5, 13], [6, 7, 8, 10, 10, 11, 12], [1, 2, 3]])
plt.ylim(0, 14)
plt.title('boxplot avec sequence')

plt.subplot(122)
plt.boxplot(np.array([[1, 2, 3], [2, 7, 8], [1, 3, 10], [2, 5, 12]]))
plt.ylim(0, 14)
plt.title('boxplot avec array 2d')
# Out:
# Text(0.5, 1.0, 'boxplot avec array 2d')

# %%
sns.heatmap(frame.corr(), annot=True, cmap='Greens')
plt.title("Matrice de corrélation entre les différentes caractéristiques des annoncées\n", fontsize=18, color='#009432')
# Out:
# Text(0.5, 1.0, 'Matrice de corrélation entre les différentes caractéristiques des annoncées\n')

# %%
g = sns.lmplot("year","selling_price",hue ='fuel_type' ,data=frame)
g

# %%
g = sns.lmplot(x="year",y="selling_price",data=frame, line_kws={'color': 'red'})

# %%
numpy.polyfit( x='year' , y='presence_price' ,deg=1, rcond = dbConnection, full = False , w = None , cov = False )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-4fb5874a44df> in <module>
# ----> 1 numpy.polyfit( x='year' , y='presence_price' ,deg=1, rcond = dbConnection, full = False , w = None , cov = False )
#
# NameError: name 'numpy' is not defined

# %%
yy=frame['present_price']
yy

# %%
from matplotlib import pyplot
pyplot.plot([1, 2, 3, 4], [4, 8, 5, 4], linestyle = ':', marker = 'o', color = 'red', markersize = 10)

# %%
x = frame['year']
y = frame['selling_price']
# plt.scatter(x, y, color='black') # Nuage de points
# plt.plot(x, y, color = 'red')
plt.hist(frame['year'],rwidth = 0.5, density= True)
plt.xlabel('Année')
plt.ylabel('Prix')

# %% [markdown]
# # 4. Régression linéaire

# %%
# df = pandas.DataFrame({'a': 'year', 'B': 'present_price'}, index = ['a', 'b', 'c'])
# plts = pyplot.plot(df, marker = 'o')
# pyplot.legend(plts, df.columns)

# %%
# 4.1 régression linéaire avec numpy.polyfit
XYear = frame["year"]
yPrix = frame["selling_price"]
model= np.polyfit( XYear,yPrix,1)
predict = np.poly1d(model)
print(type(predict))
# ageA=2015
# P=predict(ageA)
plt.scatter(XYear, yPrix, color='black') # Nuage de points
plt.plot(XYear,predict(XYear),color='r') #la droite

# %%
# 4.2 Régression lineaire scipy
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
plt.plot(x, y,'o')
plt.plot(x, slope*x + intercept, color="red" )
plt.show()

# %%
# 4.3 Régression lineaire sklearn

from sklearn.linear_model import LinearRegression
from sklearn import linear_model
x = frame[['year']]
y = frame['selling_price']
model = linear_model.LinearRegression()
results = model.fit(x,y)
print(results.coef_)
print(results.intercept_)

# %%
x = frame['year']
y=frame['selling_price']
def func(x, y):
    xmean = x.mean()
    ymean = y.mean()
    xvariance = sum([(x - xmean)**2 for x in x])
    xycovariance = 0
    for i in range(len(x)):
        xycovariance += (x[i] - xmean) * (y[i] - ymean)
    a = xycovariance / xvariance
    b = ymean - a * xmean
    return a,b
slop, intercept =func(x,y)
print(slop, intercept)

# %% [markdown]
# # 5 Creation de Class LinearRegression

# %%
class LinearRegression:
    
    def _init_(self, x, y):
        self.x = frame['year']
        self.y=frame['selling_price']

    def func(x, y):
        xmean = x.mean()
        ymean = y.mean()
        xvariance = sum([(x - xmean)**2 for x in x])
        xycovariance = 0
        for i in range(len(x)):
            xycovariance += (x[i] - xmean) * (y[i] - ymean)
        a = xycovariance / xvariance
        b = ymean - a * xmean
        return a,b
    slop, intercept =func(x,y)
    plt.scatter(x, y, color='black')
    plt.plot(x, slop*x + intercept, color="red" )
plt.show()
#     print(slop, intercept)
v = LinearRegression()

# %%
class test:
    x = []
    y = []
    slr_slope = 0
    slr_intercept = 0
    
    def __init__(self,Xs, Ys):
        self.x = Xs
        self.y = Ys
        self.fit()
    
    def fit(self):
        x_mean = self.x.mean()
        y_mean = self.y.mean()
        xvariance = sum([(x - x_mean)**2 for x in self.x])
        xycovariance = 0
        for i in range(len(x)):
            xycovariance += (self.x[i] - x_mean) * (self.y[i] - y_mean)
        self.slr_slope = xycovariance / xvariance
        self.slr_intercept = y_mean - self.slr_slope * x_mean
    
    def predict(self, x):
        return ols_slop * x + ols_intercept
    
    def render(self):
        sns.scatterplot(x=self.x, y=self.y, label='Original data')
        plt.plot(self.x, self.slr_slope * self.x + self.slr_intercept, 'red', label="Fitted line")
        plt.legend()

# %%
v = test(frame['year'], frame['selling_price'])
v.render()

# %% [markdown]
# # 5. Support Vector Machines

# %% [markdown]
# # 7. Dashboard
